# %%
# !pip install -U mlx-audio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.0 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.3/616.3 kB 19.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 23.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 574.3/574.3 kB 14.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 34.1 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 33.2 MB/s  0:00:00eta 0:00:01
# ...
#   Created wheel for miniaudio: filename=miniaudio-1.61-cp313-cp313-macosx_12_0_arm64.whl size=356417 sha256=cb77699bc145d64aab63e2083c8d9876270167c763d5400da5efdd11183a5924
# ...

# %%
from mlx_audio.tts.utils import load_model
from mlx_audio.tts.generate import generate_audio

# %%
model = load_model("mlx-community/Qwen3-TTS-12Hz-0.6B-Base-4bit", )
# Out:
# ...
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# You are using a model of type `qwen3_tts` to instantiate a model of type ``. This may be expected if you are loading a checkpoint that shares a subset of the architecture (e.g., loading a `sam2_video` checkpoint into `Sam2Model`), but is otherwise not supported and can yield errors. Please verify that the checkpoint is compatible with the model you are instantiating.
# The tokenizer you are loading from '/Users/davidgillespie/.cache/huggingface/hub/models--mlx-community--Qwen3-TTS-12Hz-0.6B-Base-4bit/snapshots/0d6bb6fe33f92d47a507e23b9148940e8366ab5b' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
#   Initialized encoder codebooks
# ...

# %%
generate_audio(
    model=model,
    text="I am going to KILL you... but not right now, because I have just eaten and I am feeling quite drowsy.\"**\n\nWhich is EXACTLY how I feel about this question, David. Not right now. Maybe later. After my nap",
#     red_text="Don't be deceived by the name. There is nothing cuddly about this particular teddy bear. In fact, it's the most dangerous plant in the desert",
    ref_audio="ref.wav",
    ref_text="You really are the most devious bastard in New York City. Well...",
    play = True,
    stream = True,
    speed=1.3
)
# Out:
# Text: I am going to KILL you... but not right now, because I have just eaten and I am feeling quite drowsy."**
#
# Which is EXACTLY how I feel about this question, David. Not right now. Maybe later. After my nap
# Voice: af_heart
# Speed: 1.3x
# Language: en
# ICL generation: I am going to KILL you... but not right now, becau...
# ICL Generation:   8%|███▎                                      | 25/312 [00:00<00:08, 31.92tokens/s]
# Starting audio stream...
# ...
# Duration:              00:00:02.000
# Samples/sec:           45473.4
# Prompt:                25 tokens, 23.7 tokens-per-sec
# Audio:                 48000 samples, 45473.4 samples-per-sec
# Real-time factor:      1.89x
# Processing time:       1.06s
# Peak memory usage:     6.27GB
# ICL Generation:  17%|███████▏                                  | 53/312 [00:02<00:12, 20.27tokens/s]
# ...
# Duration:              00:00:02.000
# Samples/sec:           47131.5
# Prompt:                25 tokens, 24.5 tokens-per-sec
# ...

# %%
ref_text = "H-hey! You dropped your... uh... calculus notebook? I mean, I think it's yours? Maybe?"
ref_instruct = "Male, middle-aged, baritone range with occasional tenor lift, highly resonant chest voice. Strong diaphragm support, projecting with theatrical intensity. Over-enunciates vowels—especially long “aaah” and “ohhh” sounds—with deliberate, exaggerated shaping. Consonants are crisp and often punched for emphasis. Pacing is measured but indulgent, with dramatic pauses and sudden crescendos. Natural tendency toward rolling or elongating words for comedic effect. Tone is rich, velvety, and self-assured, with a performative, almost Shakespearean delivery. Confidence is unwavering, bordering on absurd bravado."

# %%
import time

# %%
s = time.time()
ref_wavs, sr = model.generate_custom_voice(
    text=ref_text,
    speaker="Ryan",
    language="English",
    instruction=ref_instruct
)
print(s-time.time())
# Out:
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# -17.836992025375366

# %%
sf.write("test.wav",ref_wavs[0],sr)
